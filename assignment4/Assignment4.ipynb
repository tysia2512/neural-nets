# %% [markdown]
# # Assignment 4
#
# **Submission deadline: last lab session before or on Wednesday, 22.11.17**
#
# **Points: 11 + 4 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %% [markdown]
# # Starter code: network for Irises in Pytorch
#
#
# In the following cells a feedforward neural network has been implemented with the aid of PyTorch and its autograd mechanism. Please study the code - many network implementations follow a similar pattern.
#
# The provided network trains to nearly 100% accuracy on Iris using Batch Gradient Descent.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch.autograd import Variable
import os


class Layer(object):
    
    def train_mode(self):
        """Put layer into training mode.
        """
        pass
    
    def eval_mode(self):
        """Put layer into evalation mode.
        """
        pass
    
    @property
    def parameters(self):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out):
        self.W = Variable(torch.FloatTensor(num_in, num_out),
                          requires_grad=True)
        self.W.name = 'W'
        self.b = Variable(torch.FloatTensor(1, num_out),
                          requires_grad=True)
        self.b.name = 'b'
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    def forward(self, x):
        return x.mm(self.W) + self.b

    
class TanhLayer(Layer):
    def forward(self, x):
        return F.tanh(x)

    
class  ReLULayer(Layer):
    def forward(self, x):
        return F.relu(x)


class SoftMaxLayer(Layer):
    def forward(self, x):
        return F.softmax(x)

# %%
class FeedforwardNet(object):
    def __init__(self, layers):
        self.layers = layers

    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params

    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP.data = newP.data
    
    def train_mode(self):
        for layer in self.layers:
            layer.train_mode()
    
    def eval_mode(self):
        for layer in self.layers:
            layer.eval_mode()    
    
    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x
    
    def loss(self, outputs, targets):
        return torch.mean(-torch.log(torch.gather(
            outputs, 1, targets.unsqueeze(1))))

# %%
from sklearn import datasets
import torchvision


iris = datasets.load_iris()
IrisX = iris.data.astype(np.float32)
IrisX = (IrisX - IrisX.mean(axis=0, keepdims=True)) / IrisX.std(axis=0, keepdims=True)
IrisY = iris.target

def GD(model, x, y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """Simple batch gradient descent"""
    try:
        old_loss = np.inf
        x = Variable(torch.from_numpy(x), requires_grad=False)
#         print(x)
        y = Variable(torch.from_numpy(y.astype(np.int64)), requires_grad=False)
        model.train_mode()
        for i in xrange(max_iters):
            outputs = model.forward(x)
            loss = model.loss(outputs, y)

            loss.backward()
            for p in model.parameters:
                p.data -= p.grad.data * alpha
                # Zero gradients for the next iteration
                p.grad.data.zero_()

            loss = loss.data[0]
            if old_loss < loss:
                print "Iter: %d, loss increased!" % (i,)
            if (old_loss - loss) < tolerance:
                print "Tolerance level reached. Exiting."
                break
            if i % 1000 == 0:
                _, predictions = outputs.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / outputs.size(0)
                print "Iteration {0: >6} | loss {1: >5.2f} | err rate  {2: >5.2f}%" \
                      .format(i, loss, err_rate)
            old_loss = loss
    except KeyboardInterrupt:
        pass

# %%
model = FeedforwardNet(
    [AffineLayer(4, 10),
     TanhLayer(),
     AffineLayer(10, 3),
     SoftMaxLayer(),
    ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        # p.data.normal_(0, 0.05)
        p.data.uniform_(-0.1, 0.1)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# Train
GD(model, IrisX, IrisY, alpha=1e-1, tolerance=1e-7)
# Out:
# Iteration      0 | loss  1.09 | err rate  48.00%
# Iteration   1000 | loss  0.05 | err rate   2.00%
# Iteration   2000 | loss  0.04 | err rate   2.00%
# Iteration   3000 | loss  0.04 | err rate   1.33%
# Iteration   4000 | loss  0.04 | err rate   1.33%
# Iteration   5000 | loss  0.04 | err rate   1.33%
# Iteration   6000 | loss  0.04 | err rate   1.33%
# Iteration   7000 | loss  0.04 | err rate   1.33%
# Iteration   8000 | loss  0.04 | err rate   1.33%
# Iteration   9000 | loss  0.04 | err rate   1.33%
# Iteration  10000 | loss  0.04 | err rate   1.33%
# Iteration  11000 | loss  0.04 | err rate   1.33%
# Iteration  12000 | loss  0.04 | err rate   1.33%
# Iteration  13000 | loss  0.04 | err rate   1.33%
# Iteration  14000 | loss  0.04 | err rate   1.33%
# Iteration  15000 | loss  0.04 | err rate   1.33%
# Iteration  16000 | loss  0.04 | err rate   1.33%
# Iteration  17000 | loss  0.04 | err rate   1.33%
# Iteration  18000 | loss  0.04 | err rate   1.33%
# Iteration  19000 | loss  0.04 | err rate   1.33%
# Iteration  20000 | loss  0.04 | err rate   1.33%
# Iteration  21000 | loss  0.03 | err rate   1.33%
# Iteration  22000 | loss  0.03 | err rate   1.33%
# Iteration  23000 | loss  0.03 | err rate   1.33%
# Iteration  24000 | loss  0.03 | err rate   1.33%
# Iteration  25000 | loss  0.03 | err rate   1.33%
# Iteration  26000 | loss  0.03 | err rate   1.33%
# Iteration  27000 | loss  0.03 | err rate   1.33%
# Iteration  28000 | loss  0.03 | err rate   0.67%
# Iteration  29000 | loss  0.02 | err rate   0.67%
# Iteration  30000 | loss  0.02 | err rate   0.67%
# Iteration  31000 | loss  0.02 | err rate   0.67%
# Iteration  32000 | loss  0.02 | err rate   0.67%
# Iteration  33000 | loss  0.01 | err rate   0.67%
# Iteration  34000 | loss  0.01 | err rate   0.67%
# Iteration  35000 | loss  0.01 | err rate   0.00%
# Iteration  36000 | loss  0.01 | err rate   0.00%
# Iteration  37000 | loss  0.01 | err rate   0.00%
# Iteration  38000 | loss  0.01 | err rate   0.00%
# Iteration  39000 | loss  0.01 | err rate   0.00%
# Iteration  40000 | loss  0.01 | err rate   0.00%
# Iteration  41000 | loss  0.01 | err rate   0.00%
# Iteration  42000 | loss  0.01 | err rate   0.00%
# Iteration  43000 | loss  0.01 | err rate   0.00%
# Iteration  44000 | loss  0.00 | err rate   0.00%
# Iteration  45000 | loss  0.00 | err rate   0.00%
# Iteration  46000 | loss  0.00 | err rate   0.00%
# Iteration  47000 | loss  0.00 | err rate   0.00%
# Iteration  48000 | loss  0.00 | err rate   0.00%
# Iteration  49000 | loss  0.00 | err rate   0.00%
# Iteration  50000 | loss  0.00 | err rate   0.00%
# Iteration  51000 | loss  0.00 | err rate   0.00%
# Iteration  52000 | loss  0.00 | err rate   0.00%
# Iteration  53000 | loss  0.00 | err rate   0.00%
# Iteration  54000 | loss  0.00 | err rate   0.00%
# Iteration  55000 | loss  0.00 | err rate   0.00%
# Iteration  56000 | loss  0.00 | err rate   0.00%
# Tolerance level reached. Exiting.

# %% [markdown]
# # Starter code for MNIST and SGD scaffolding

# %%
import torch
import torchvision


batch_size = 128
data_path = os.environ.get('PYTORCH_DATA_PATH', '../data')

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}
# print(_train.train_data[0])

# %%
def compute_error_rate(model, data_loader, cuda=False):
    model.eval_mode()
    num_errs = 0.0
    num_examples = 0
    for x, y in data_loader:
        if cuda:
            x = x.cuda()
            y = y.cuda()
        x = Variable(x.view(x.size(0), -1), volatile=True)
        y = Variable(y, volatile=True)
        outputs = model.forward(x)
        _, predictions = outputs.data.max(dim=1)
        num_errs += (predictions != y.data).sum()
        num_examples += x.size(0)
    return 100.0 * num_errs / num_examples

def SGD(model, data_loaders, alpha=1e-4, num_epochs=1, patience_expansion=1.5,
        log_every=100, cuda=False):
    if cuda:
        for p in model.parameters:
            p.data = p.data.cuda()
    #
    # TODO: Initialize momentum variables
    # Hint: You need one velocity matrix for each parameter
    velocities = [np.zeros(pars.data.shape) for pars in model.parameters]
#     print(model.parameters)
#     print(velocities)
    iter_ = 0
    epoch = 0
    best_params = None
    best_val_err = np.inf
    history = {'train_losses': [], 'train_errs': [], 'val_errs': []}
    print('Training the model!')
    print('Interrupt at any time to evaluate the best validation model so far.')
    
#     alphaB = 1.
#     alphaC = 1e4
    alpha0 = 1e-2
    alphaC = 0.995
    try:
        while epoch < num_epochs:
            model.train_mode()
            epoch += 1
            for x, y in data_loaders['train']:
                if cuda:
                    x = x.cuda()
                    y = y.cuda()
                iter_ += 1
                x = Variable(x.view(x.size(0), -1), requires_grad=False)
                y = Variable(y, requires_grad=False)
                
                out = model.forward(x)
                loss = model.loss(out, y)
                loss.backward()
                _, predictions = out.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / out.size(0)

                history['train_losses'].append(loss.data[0])
                history['train_errs'].append(err_rate)

                for p, v in zip(model.parameters, velocities):
                    if p.name == 'W':
                        pass
                    #
                    # TODO: Implement weight decay addition to gradients
                    p.grad.data += p.data * 1e-4 #beta
                    
                    #
                    # TODO: Update learning rate
                    # Hint: Use the iteration counter i
#                     alpha = alpha0 * alphaC ** iter_ #based on first equation from slides
                    alpha = 70.0 / (10000.0 + iter_)
                    
                    #
                    # TODO: Set the momentum constant 
                    epsilon = 0.98
                    
                    #
                    # TODO: Implement velocity update in momentum
#                     print(v)
#                     print(alpha * p.grad.data)
                    v = (epsilon * torch.Tensor(v)) + (alpha * p.grad.data)
                    #
                    
                    #
                    # TODO: Set a more sensible learning rule here,
                    #       using your learning rate schedule and momentum
                    # 
#                     p.data -= alpha * p.grad.data
                    p.data -= v
                    # Zero gradients for the next iteration
                    p.grad.data.zero_()

                if iter_ % log_every == 0:
                    print "Minibatch {0: >6}  | loss {1: >5.2f} | err rate {2: >5.2f}%" \
                          .format(iter_, loss.data[0], err_rate)
            
            val_err_rate = compute_error_rate(model, data_loaders['valid'], cuda)
            history['val_errs'].append((iter_, val_err_rate))
            
            if val_err_rate < best_val_err:
                # Adjust num of epochs
                num_epochs = int(np.maximum(num_epochs, epoch * patience_expansion + 1))
                best_epoch = epoch
                best_val_err = val_err_rate
                best_params = [p.clone().cpu() for p in model.parameters]
            m = "After epoch {0: >2} | valid err rate: {1: >5.2f}% | doing {2: >3} epochs" \
                .format(epoch, val_err_rate, num_epochs)
            print '{0}\n{1}\n{0}'.format('-' * len(m), m)

    except KeyboardInterrupt:
        pass
    if best_params is not None:
        print "\nLoading best params on validation set (epoch %d)\n" %(best_epoch)
        model.parameters = best_params
    plot_history(history)

def plot_history(history):
    figsize(16, 4)
    subplot(1,2,1)
    train_loss = np.array(history['train_losses'])
    semilogy(np.arange(train_loss.shape[0]), train_loss, label='batch train loss')
    legend()
        
    subplot(1,2,2)
    train_errs = np.array(history['train_errs'])
    plot(np.arange(train_errs.shape[0]), train_errs, label='batch train error rate')
    val_errs = np.array(history['val_errs'])
    plot(val_errs[:,0], val_errs[:,1], label='validation error rate', color='r')
    ylim(0,20)
    legend()

# %% [markdown]
# # Problem 1: Stochastic Gradient Descent [3p]
# Implement the following additions to the SGD code provided above:
#   1. **[1p]** momentum
#   2. **[1p]** learning rate schedule
#   3. **[1p]** weight decay, in which we additionally minimize for each weight matrix (but typically not the bias) the sum of its elements squared. One way to implement it is to use function `model.parameters` and select all parameters whose names are "`W`" and not "`b`".

# %% [markdown]
# # Problem 2: Tuning the Network for MNIST [4p]
#
# Tune the following network to reach **validation error rate below 1.9%**.
# This should result in a **test error rate below 2%**. To
# tune the network you will need to:
# 1. Choose the number of layers (more than 1, less than 5);
# 2. Choose the number of neurons in each layer (more than 100,
#     less than 5000);
# 3. Pick proper weight initialization;
# 4. Pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches);
# 5. Pick a momentum constant (probably a constant one will be OK).

# %%
#
# TODO: Pick a network architecture here.
#       The one below is just softmax regression.
#

model = FeedforwardNet(
    [
     AffineLayer(784, 1500),
     ReLULayer(),
     AffineLayer(1500, 10),
     SoftMaxLayer()
    ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
#         p.data.normal_(0, 0.2)
        p.data.uniform_(-0.1, 0.1)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(model, mnist_loaders, alpha=1e-1, cuda=False)

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.67 | err rate 16.41%
# Minibatch    200  | loss  0.38 | err rate 12.50%
# Minibatch    300  | loss  0.27 | err rate  6.25%
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  8.81% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.34 | err rate 10.16%
# Minibatch    500  | loss  0.28 | err rate 10.16%
# Minibatch    600  | loss  0.33 | err rate  7.03%
# Minibatch    700  | loss  0.24 | err rate  8.59%
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  7.33% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.41 | err rate 10.94%
# Minibatch    900  | loss  0.28 | err rate  9.38%
# Minibatch   1000  | loss  0.21 | err rate  6.25%
# Minibatch   1100  | loss  0.18 | err rate  3.12%
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  6.42% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.29 | err rate  7.81%
# Minibatch   1300  | loss  0.19 | err rate  4.69%
# Minibatch   1400  | loss  0.13 | err rate  3.91%
# Minibatch   1500  | loss  0.19 | err rate  5.47%
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  5.85% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.17 | err rate  4.69%
# Minibatch   1700  | loss  0.19 | err rate  1.56%
# Minibatch   1800  | loss  0.23 | err rate  5.47%
# Minibatch   1900  | loss  0.26 | err rate  7.81%
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  5.26% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.17 | err rate  4.69%
# Minibatch   2100  | loss  0.19 | err rate  5.47%
# Minibatch   2200  | loss  0.31 | err rate  7.03%
# Minibatch   2300  | loss  0.19 | err rate  4.69%
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  4.97% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.16 | err rate  4.69%
# Minibatch   2500  | loss  0.14 | err rate  3.12%
# Minibatch   2600  | loss  0.11 | err rate  2.34%
# Minibatch   2700  | loss  0.17 | err rate  4.69%
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  4.72% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.10 | err rate  3.91%
# Minibatch   2900  | loss  0.09 | err rate  2.34%
# Minibatch   3000  | loss  0.20 | err rate  6.25%
# Minibatch   3100  | loss  0.16 | err rate  3.91%
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  4.59% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.25 | err rate  7.81%
# Minibatch   3300  | loss  0.08 | err rate  1.56%
# Minibatch   3400  | loss  0.06 | err rate  0.78%
# Minibatch   3500  | loss  0.07 | err rate  2.34%
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  4.33% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.14 | err rate  3.12%
# Minibatch   3700  | loss  0.14 | err rate  4.69%
# Minibatch   3800  | loss  0.11 | err rate  2.34%
# Minibatch   3900  | loss  0.18 | err rate  7.03%
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  4.20% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.07 | err rate  1.56%
# Minibatch   4100  | loss  0.16 | err rate  3.91%
# Minibatch   4200  | loss  0.11 | err rate  1.56%
# Minibatch   4300  | loss  0.24 | err rate  9.38%
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  4.10% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.19 | err rate  6.25%
# Minibatch   4500  | loss  0.18 | err rate  3.12%
# Minibatch   4600  | loss  0.23 | err rate  7.81%
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  4.05% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.13 | err rate  3.12%
# Minibatch   4800  | loss  0.13 | err rate  4.69%
# Minibatch   4900  | loss  0.14 | err rate  3.12%
# Minibatch   5000  | loss  0.21 | err rate  5.47%
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  3.91% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.15 | err rate  6.25%
# Minibatch   5200  | loss  0.07 | err rate  0.78%
# Minibatch   5300  | loss  0.10 | err rate  1.56%
# Minibatch   5400  | loss  0.16 | err rate  4.69%
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  3.91% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.22 | err rate  5.47%
# Minibatch   5600  | loss  0.11 | err rate  2.34%
# Minibatch   5700  | loss  0.12 | err rate  4.69%
# Minibatch   5800  | loss  0.13 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  3.93% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5900  | loss  0.08 | err rate  1.56%
# Minibatch   6000  | loss  0.11 | err rate  1.56%
# Minibatch   6100  | loss  0.08 | err rate  3.12%
# Minibatch   6200  | loss  0.20 | err rate  4.69%
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  3.70% | doing  25 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.12 | err rate  3.12%
# Minibatch   6400  | loss  0.07 | err rate  0.78%
# Minibatch   6500  | loss  0.11 | err rate  3.91%
# Minibatch   6600  | loss  0.07 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  3.73% | doing  25 epochs
# ----------------------------------------------------------
# Minibatch   6700  | loss  0.06 | err rate  1.56%
# Minibatch   6800  | loss  0.08 | err rate  2.34%
# Minibatch   6900  | loss  0.11 | err rate  1.56%
# Minibatch   7000  | loss  0.09 | err rate  3.12%
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  3.63% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.05 | err rate  1.56%
# Minibatch   7200  | loss  0.10 | err rate  3.12%
# Minibatch   7300  | loss  0.11 | err rate  3.12%
# Minibatch   7400  | loss  0.13 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  3.62% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   7500  | loss  0.08 | err rate  1.56%
# Minibatch   7600  | loss  0.09 | err rate  1.56%
# Minibatch   7700  | loss  0.09 | err rate  1.56%
# Minibatch   7800  | loss  0.14 | err rate  5.47%
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  3.58% | doing  31 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.12 | err rate  3.12%
# Minibatch   8000  | loss  0.09 | err rate  3.12%
# Minibatch   8100  | loss  0.11 | err rate  5.47%
# Minibatch   8200  | loss  0.11 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  3.52% | doing  32 epochs
# ----------------------------------------------------------
# Minibatch   8300  | loss  0.09 | err rate  2.34%
# Minibatch   8400  | loss  0.12 | err rate  3.12%
# Minibatch   8500  | loss  0.10 | err rate  1.56%
# Minibatch   8600  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  3.47% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.16 | err rate  3.91%
# Minibatch   8800  | loss  0.09 | err rate  2.34%
# Minibatch   8900  | loss  0.09 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  3.49% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch   9000  | loss  0.09 | err rate  2.34%
# Minibatch   9100  | loss  0.09 | err rate  2.34%
# Minibatch   9200  | loss  0.18 | err rate  3.91%
# Minibatch   9300  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  3.46% | doing  37 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.12 | err rate  3.91%
# Minibatch   9500  | loss  0.09 | err rate  2.34%
# Minibatch   9600  | loss  0.13 | err rate  3.91%
# Minibatch   9700  | loss  0.12 | err rate  3.12%
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  3.41% | doing  38 epochs
# ----------------------------------------------------------
# Minibatch   9800  | loss  0.11 | err rate  3.91%
# Minibatch   9900  | loss  0.04 | err rate  0.78%
# Minibatch  10000  | loss  0.04 | err rate  0.00%
# Minibatch  10100  | loss  0.13 | err rate  3.91%
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  3.44% | doing  38 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.14 | err rate  3.12%
# Minibatch  10300  | loss  0.03 | err rate  0.00%
# Minibatch  10400  | loss  0.07 | err rate  1.56%
# Minibatch  10500  | loss  0.06 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  3.35% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  10600  | loss  0.09 | err rate  2.34%
# Minibatch  10700  | loss  0.17 | err rate  5.47%
# Minibatch  10800  | loss  0.06 | err rate  2.34%
# Minibatch  10900  | loss  0.08 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  3.32% | doing  43 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.05 | err rate  1.56%
# Minibatch  11100  | loss  0.07 | err rate  1.56%
# Minibatch  11200  | loss  0.07 | err rate  3.12%
# Minibatch  11300  | loss  0.05 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  3.30% | doing  44 epochs
# ----------------------------------------------------------
# Minibatch  11400  | loss  0.11 | err rate  3.12%
# Minibatch  11500  | loss  0.11 | err rate  3.12%
# Minibatch  11600  | loss  0.06 | err rate  0.78%
# Minibatch  11700  | loss  0.12 | err rate  6.25%
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  3.29% | doing  46 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.09 | err rate  3.91%
# Minibatch  11900  | loss  0.14 | err rate  3.12%
# Minibatch  12000  | loss  0.03 | err rate  0.00%
# Minibatch  12100  | loss  0.10 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  3.30% | doing  46 epochs
# ----------------------------------------------------------
# Minibatch  12200  | loss  0.06 | err rate  1.56%
# Minibatch  12300  | loss  0.08 | err rate  3.12%
# Minibatch  12400  | loss  0.05 | err rate  1.56%
# Minibatch  12500  | loss  0.11 | err rate  3.91%
# ----------------------------------------------------------
# After epoch 32 | valid err rate:  3.26% | doing  49 epochs
# ----------------------------------------------------------
# Minibatch  12600  | loss  0.02 | err rate  0.00%
# Minibatch  12700  | loss  0.08 | err rate  2.34%
# Minibatch  12800  | loss  0.08 | err rate  0.78%
# Minibatch  12900  | loss  0.07 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 33 | valid err rate:  3.25% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  13000  | loss  0.06 | err rate  0.78%
# Minibatch  13100  | loss  0.10 | err rate  2.34%
# Minibatch  13200  | loss  0.12 | err rate  3.12%
# ----------------------------------------------------------
# After epoch 34 | valid err rate:  3.24% | doing  52 epochs
# ----------------------------------------------------------
# Minibatch  13300  | loss  0.06 | err rate  0.78%
# Minibatch  13400  | loss  0.08 | err rate  1.56%
# Minibatch  13500  | loss  0.12 | err rate  1.56%
# Minibatch  13600  | loss  0.10 | err rate  3.12%
# ----------------------------------------------------------
# After epoch 35 | valid err rate:  3.20% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  13700  | loss  0.07 | err rate  0.78%
# Minibatch  13800  | loss  0.11 | err rate  2.34%
# Minibatch  13900  | loss  0.04 | err rate  0.00%
# Minibatch  14000  | loss  0.11 | err rate  3.12%
# ----------------------------------------------------------
# After epoch 36 | valid err rate:  3.22% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  14100  | loss  0.07 | err rate  1.56%
# Minibatch  14200  | loss  0.08 | err rate  2.34%
# Minibatch  14300  | loss  0.05 | err rate  1.56%
# Minibatch  14400  | loss  0.05 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 37 | valid err rate:  3.23% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  14500  | loss  0.03 | err rate  0.78%
# Minibatch  14600  | loss  0.09 | err rate  3.12%
# Minibatch  14700  | loss  0.05 | err rate  1.56%
# Minibatch  14800  | loss  0.12 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 38 | valid err rate:  3.22% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  14900  | loss  0.08 | err rate  3.91%
# Minibatch  15000  | loss  0.04 | err rate  0.78%
# Minibatch  15100  | loss  0.06 | err rate  1.56%
# Minibatch  15200  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 39 | valid err rate:  3.17% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  15300  | loss  0.12 | err rate  5.47%
# Minibatch  15400  | loss  0.08 | err rate  1.56%
# Minibatch  15500  | loss  0.05 | err rate  0.00%
# Minibatch  15600  | loss  0.07 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 40 | valid err rate:  3.09% | doing  61 epochs
# ----------------------------------------------------------
# Minibatch  15700  | loss  0.09 | err rate  2.34%
# Minibatch  15800  | loss  0.04 | err rate  0.78%
# Minibatch  15900  | loss  0.03 | err rate  0.00%
# Minibatch  16000  | loss  0.09 | err rate  3.12%
# ----------------------------------------------------------
# After epoch 41 | valid err rate:  3.17% | doing  61 epochs
# ----------------------------------------------------------
# Minibatch  16100  | loss  0.12 | err rate  3.91%
# Minibatch  16200  | loss  0.08 | err rate  1.56%
# Minibatch  16300  | loss  0.04 | err rate  0.78%
# Minibatch  16400  | loss  0.06 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 42 | valid err rate:  3.13% | doing  61 epochs
# ----------------------------------------------------------
# Minibatch  16500  | loss  0.08 | err rate  2.34%
# Minibatch  16600  | loss  0.02 | err rate  0.00%
# Minibatch  16700  | loss  0.07 | err rate  1.56%
# Minibatch  16800  | loss  0.07 | err rate  3.91%
# ----------------------------------------------------------
# After epoch 43 | valid err rate:  3.12% | doing  61 epochs
# ----------------------------------------------------------
# Minibatch  16900  | loss  0.12 | err rate  3.12%
# Minibatch  17000  | loss  0.10 | err rate  2.34%
# Minibatch  17100  | loss  0.04 | err rate  0.78%
# Minibatch  17200  | loss  0.05 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 44 | valid err rate:  3.08% | doing  67 epochs
# ----------------------------------------------------------
# Minibatch  17300  | loss  0.10 | err rate  1.56%
# Minibatch  17400  | loss  0.15 | err rate  3.91%
# Minibatch  17500  | loss  0.05 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 45 | valid err rate:  3.07% | doing  68 epochs
# ----------------------------------------------------------
# Minibatch  17600  | loss  0.04 | err rate  0.00%
# Minibatch  17700  | loss  0.05 | err rate  0.78%
# Minibatch  17800  | loss  0.05 | err rate  0.78%
# Minibatch  17900  | loss  0.05 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 46 | valid err rate:  3.08% | doing  68 epochs
# ----------------------------------------------------------
# Minibatch  18000  | loss  0.04 | err rate  0.78%
# Minibatch  18100  | loss  0.06 | err rate  1.56%
# Minibatch  18200  | loss  0.06 | err rate  1.56%
# Minibatch  18300  | loss  0.11 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 47 | valid err rate:  3.10% | doing  68 epochs
# ----------------------------------------------------------
# Minibatch  18400  | loss  0.04 | err rate  1.56%
# Minibatch  18500  | loss  0.13 | err rate  3.12%
# Minibatch  18600  | loss  0.05 | err rate  0.78%
# Minibatch  18700  | loss  0.09 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 48 | valid err rate:  3.04% | doing  73 epochs
# ----------------------------------------------------------
# Minibatch  18800  | loss  0.08 | err rate  1.56%
# Minibatch  18900  | loss  0.10 | err rate  2.34%
# Minibatch  19000  | loss  0.08 | err rate  1.56%
# Minibatch  19100  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 49 | valid err rate:  3.08% | doing  73 epochs
# ----------------------------------------------------------
# Minibatch  19200  | loss  0.08 | err rate  2.34%
# Minibatch  19300  | loss  0.07 | err rate  1.56%
# Minibatch  19400  | loss  0.09 | err rate  2.34%
# Minibatch  19500  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 50 | valid err rate:  3.03% | doing  76 epochs
# ----------------------------------------------------------
# Minibatch  19600  | loss  0.05 | err rate  1.56%
# Minibatch  19700  | loss  0.05 | err rate  0.78%
# Minibatch  19800  | loss  0.04 | err rate  0.00%
# Minibatch  19900  | loss  0.08 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 51 | valid err rate:  3.02% | doing  77 epochs
# ----------------------------------------------------------
# Minibatch  20000  | loss  0.05 | err rate  0.00%
# Minibatch  20100  | loss  0.05 | err rate  1.56%
# Minibatch  20200  | loss  0.04 | err rate  1.56%
# Minibatch  20300  | loss  0.06 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 52 | valid err rate:  3.05% | doing  77 epochs
# ----------------------------------------------------------
# Minibatch  20400  | loss  0.08 | err rate  2.34%
# Minibatch  20500  | loss  0.04 | err rate  0.78%
# Minibatch  20600  | loss  0.03 | err rate  0.00%
# Minibatch  20700  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 53 | valid err rate:  3.08% | doing  77 epochs
# ----------------------------------------------------------
# Minibatch  20800  | loss  0.07 | err rate  1.56%
# Minibatch  20900  | loss  0.03 | err rate  0.78%
# Minibatch  21000  | loss  0.04 | err rate  0.78%
# Minibatch  21100  | loss  0.07 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 54 | valid err rate:  3.01% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  21200  | loss  0.04 | err rate  0.78%
# Minibatch  21300  | loss  0.05 | err rate  0.78%
# Minibatch  21400  | loss  0.05 | err rate  0.78%
# Minibatch  21500  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 55 | valid err rate:  3.05% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  21600  | loss  0.03 | err rate  0.78%
# Minibatch  21700  | loss  0.05 | err rate  0.78%
# Minibatch  21800  | loss  0.06 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 56 | valid err rate:  2.98% | doing  85 epochs
# ----------------------------------------------------------
# Minibatch  21900  | loss  0.03 | err rate  0.78%
# Minibatch  22000  | loss  0.05 | err rate  0.78%
# Minibatch  22100  | loss  0.10 | err rate  3.12%
# Minibatch  22200  | loss  0.05 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 57 | valid err rate:  3.01% | doing  85 epochs
# ----------------------------------------------------------
# Minibatch  22300  | loss  0.08 | err rate  4.69%
# Minibatch  22400  | loss  0.03 | err rate  1.56%
# Minibatch  22500  | loss  0.07 | err rate  2.34%
# Minibatch  22600  | loss  0.07 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 58 | valid err rate:  2.99% | doing  85 epochs
# ----------------------------------------------------------
# Minibatch  22700  | loss  0.05 | err rate  0.00%
# Minibatch  22800  | loss  0.07 | err rate  1.56%
# Minibatch  22900  | loss  0.04 | err rate  1.56%
# Minibatch  23000  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 59 | valid err rate:  3.01% | doing  85 epochs
# ----------------------------------------------------------
# Minibatch  23100  | loss  0.03 | err rate  0.78%
# Minibatch  23200  | loss  0.04 | err rate  0.78%
# Minibatch  23300  | loss  0.10 | err rate  3.91%
# Minibatch  23400  | loss  0.07 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 60 | valid err rate:  3.00% | doing  85 epochs
# ----------------------------------------------------------
# Minibatch  23500  | loss  0.04 | err rate  0.78%
# Minibatch  23600  | loss  0.05 | err rate  0.78%
# Minibatch  23700  | loss  0.03 | err rate  0.78%
# Minibatch  23800  | loss  0.06 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 61 | valid err rate:  2.96% | doing  92 epochs
# ----------------------------------------------------------
# Minibatch  23900  | loss  0.09 | err rate  2.34%
# Minibatch  24000  | loss  0.13 | err rate  3.12%
# Minibatch  24100  | loss  0.07 | err rate  1.56%
# Minibatch  24200  | loss  0.02 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 62 | valid err rate:  2.96% | doing  92 epochs
# ----------------------------------------------------------
# Minibatch  24300  | loss  0.05 | err rate  0.78%
# Minibatch  24400  | loss  0.05 | err rate  0.00%
# Minibatch  24500  | loss  0.06 | err rate  2.34%
# Minibatch  24600  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 63 | valid err rate:  3.01% | doing  92 epochs
# ----------------------------------------------------------
# Minibatch  24700  | loss  0.05 | err rate  1.56%
# Minibatch  24800  | loss  0.07 | err rate  1.56%
# Minibatch  24900  | loss  0.05 | err rate  0.78%
# Minibatch  25000  | loss  0.05 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 64 | valid err rate:  3.00% | doing  92 epochs
# ----------------------------------------------------------
# Minibatch  25100  | loss  0.06 | err rate  1.56%
# Minibatch  25200  | loss  0.04 | err rate  0.00%
# Minibatch  25300  | loss  0.07 | err rate  1.56%
# Minibatch  25400  | loss  0.07 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 65 | valid err rate:  3.01% | doing  92 epochs
# ----------------------------------------------------------
# Minibatch  25500  | loss  0.07 | err rate  2.34%
# Minibatch  25600  | loss  0.06 | err rate  1.56%
# Minibatch  25700  | loss  0.09 | err rate  3.91%
# Minibatch  25800  | loss  0.04 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 66 | valid err rate:  2.98% | doing  92 epochs
# ----------------------------------------------------------
# Minibatch  25900  | loss  0.05 | err rate  1.56%
# Minibatch  26000  | loss  0.02 | err rate  0.00%
# Minibatch  26100  | loss  0.09 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 67 | valid err rate:  2.98% | doing  92 epochs
# ----------------------------------------------------------
# Minibatch  26200  | loss  0.02 | err rate  0.00%
# Minibatch  26300  | loss  0.04 | err rate  0.00%
# Minibatch  26400  | loss  0.07 | err rate  1.56%
# Minibatch  26500  | loss  0.12 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 68 | valid err rate:  3.01% | doing  92 epochs
# ----------------------------------------------------------
# Minibatch  26600  | loss  0.06 | err rate  0.78%
# Minibatch  26700  | loss  0.10 | err rate  2.34%
# Minibatch  26800  | loss  0.03 | err rate  0.00%
# Minibatch  26900  | loss  0.05 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 69 | valid err rate:  2.99% | doing  92 epochs
# ----------------------------------------------------------
# Minibatch  27000  | loss  0.07 | err rate  2.34%
# Minibatch  27100  | loss  0.04 | err rate  0.00%
# Minibatch  27200  | loss  0.03 | err rate  0.00%
# Minibatch  27300  | loss  0.06 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 70 | valid err rate:  2.95% | doing 106 epochs
# ----------------------------------------------------------
# Minibatch  27400  | loss  0.04 | err rate  0.78%
# Minibatch  27500  | loss  0.05 | err rate  0.00%
# Minibatch  27600  | loss  0.06 | err rate  0.78%
# Minibatch  27700  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 71 | valid err rate:  2.98% | doing 106 epochs
# ----------------------------------------------------------
# Minibatch  27800  | loss  0.06 | err rate  3.12%
# Minibatch  27900  | loss  0.04 | err rate  0.78%
# Minibatch  28000  | loss  0.02 | err rate  0.00%
# Minibatch  28100  | loss  0.07 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 72 | valid err rate:  2.97% | doing 106 epochs
# ----------------------------------------------------------
# Minibatch  28200  | loss  0.07 | err rate  2.34%
# Minibatch  28300  | loss  0.06 | err rate  1.56%
# Minibatch  28400  | loss  0.04 | err rate  1.56%
# Minibatch  28500  | loss  0.08 | err rate  3.12%
# ----------------------------------------------------------
# After epoch 73 | valid err rate:  3.01% | doing 106 epochs
# ----------------------------------------------------------
# Minibatch  28600  | loss  0.05 | err rate  0.78%
# Minibatch  28700  | loss  0.03 | err rate  1.56%
# Minibatch  28800  | loss  0.17 | err rate  3.91%
# Minibatch  28900  | loss  0.03 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 74 | valid err rate:  2.98% | doing 106 epochs
# ----------------------------------------------------------
# Minibatch  29000  | loss  0.05 | err rate  0.00%
# Minibatch  29100  | loss  0.06 | err rate  0.78%
# Minibatch  29200  | loss  0.04 | err rate  0.00%
# Minibatch  29300  | loss  0.06 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 75 | valid err rate:  2.96% | doing 106 epochs
# ----------------------------------------------------------
# Minibatch  29400  | loss  0.05 | err rate  0.78%
# Minibatch  29500  | loss  0.03 | err rate  0.00%
# Minibatch  29600  | loss  0.05 | err rate  2.34%
# Minibatch  29700  | loss  0.03 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 76 | valid err rate:  2.94% | doing 115 epochs
# ----------------------------------------------------------
# Minibatch  29800  | loss  0.10 | err rate  1.56%
# Minibatch  29900  | loss  0.09 | err rate  2.34%
# Minibatch  30000  | loss  0.05 | err rate  0.78%
# Minibatch  30100  | loss  0.07 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 77 | valid err rate:  2.97% | doing 115 epochs
# ----------------------------------------------------------
# Minibatch  30200  | loss  0.05 | err rate  1.56%
# Minibatch  30300  | loss  0.06 | err rate  1.56%
# Minibatch  30400  | loss  0.10 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 78 | valid err rate:  2.93% | doing 118 epochs
# ----------------------------------------------------------
# Minibatch  30500  | loss  0.03 | err rate  0.00%
# Minibatch  30600  | loss  0.03 | err rate  0.00%
# Minibatch  30700  | loss  0.05 | err rate  0.78%
# Minibatch  30800  | loss  0.04 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 79 | valid err rate:  2.91% | doing 119 epochs
# ----------------------------------------------------------
# Minibatch  30900  | loss  0.04 | err rate  0.00%
# Minibatch  31000  | loss  0.03 | err rate  0.00%
# Minibatch  31100  | loss  0.04 | err rate  0.00%
# Minibatch  31200  | loss  0.03 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 80 | valid err rate:  2.96% | doing 119 epochs
# ----------------------------------------------------------
# Minibatch  31300  | loss  0.10 | err rate  2.34%
# Minibatch  31400  | loss  0.05 | err rate  0.00%
# Minibatch  31500  | loss  0.02 | err rate  0.00%
# Minibatch  31600  | loss  0.03 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 81 | valid err rate:  2.92% | doing 119 epochs
# ----------------------------------------------------------
# Minibatch  31700  | loss  0.07 | err rate  2.34%
# Minibatch  31800  | loss  0.03 | err rate  0.00%
# Minibatch  31900  | loss  0.05 | err rate  0.78%
# Minibatch  32000  | loss  0.03 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 82 | valid err rate:  2.91% | doing 119 epochs
# ----------------------------------------------------------
# Minibatch  32100  | loss  0.09 | err rate  2.34%
# Minibatch  32200  | loss  0.04 | err rate  0.78%
# Minibatch  32300  | loss  0.05 | err rate  1.56%
# Minibatch  32400  | loss  0.03 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 83 | valid err rate:  2.94% | doing 119 epochs
# ----------------------------------------------------------
# Minibatch  32500  | loss  0.06 | err rate  3.12%
# Minibatch  32600  | loss  0.05 | err rate  0.78%
# Minibatch  32700  | loss  0.01 | err rate  0.00%
# Minibatch  32800  | loss  0.03 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 84 | valid err rate:  2.90% | doing 127 epochs
# ----------------------------------------------------------
# Minibatch  32900  | loss  0.05 | err rate  0.78%
# Minibatch  33000  | loss  0.09 | err rate  2.34%
# Minibatch  33100  | loss  0.04 | err rate  0.00%
# Minibatch  33200  | loss  0.05 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 85 | valid err rate:  2.94% | doing 127 epochs
# ----------------------------------------------------------
# Minibatch  33300  | loss  0.10 | err rate  3.91%
# Minibatch  33400  | loss  0.02 | err rate  0.00%
# Minibatch  33500  | loss  0.03 | err rate  0.00%
# Minibatch  33600  | loss  0.10 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 86 | valid err rate:  2.92% | doing 127 epochs
# ----------------------------------------------------------
# Minibatch  33700  | loss  0.02 | err rate  0.00%
# Minibatch  33800  | loss  0.04 | err rate  0.00%
# Minibatch  33900  | loss  0.11 | err rate  4.69%
# Minibatch  34000  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 87 | valid err rate:  2.94% | doing 127 epochs
# ----------------------------------------------------------
# Minibatch  34100  | loss  0.03 | err rate  0.78%
# Minibatch  34200  | loss  0.03 | err rate  0.78%
# Minibatch  34300  | loss  0.03 | err rate  0.78%
# Minibatch  34400  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 88 | valid err rate:  2.91% | doing 127 epochs
# ----------------------------------------------------------
# Minibatch  34500  | loss  0.08 | err rate  1.56%
# Minibatch  34600  | loss  0.08 | err rate  1.56%
# Minibatch  34700  | loss  0.06 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 89 | valid err rate:  2.90% | doing 127 epochs
# ----------------------------------------------------------
# Minibatch  34800  | loss  0.03 | err rate  0.78%
# Minibatch  34900  | loss  0.03 | err rate  0.00%
# Minibatch  35000  | loss  0.05 | err rate  1.56%
# Minibatch  35100  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 90 | valid err rate:  2.88% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  35200  | loss  0.05 | err rate  1.56%
# Minibatch  35300  | loss  0.03 | err rate  0.78%
# Minibatch  35400  | loss  0.03 | err rate  0.78%
# Minibatch  35500  | loss  0.02 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 91 | valid err rate:  2.92% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  35600  | loss  0.14 | err rate  2.34%
# Minibatch  35700  | loss  0.04 | err rate  1.56%
# Minibatch  35800  | loss  0.03 | err rate  0.00%
# Minibatch  35900  | loss  0.06 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 92 | valid err rate:  2.91% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  36000  | loss  0.04 | err rate  1.56%
# Minibatch  36100  | loss  0.03 | err rate  0.00%
# Minibatch  36200  | loss  0.03 | err rate  0.00%
# Minibatch  36300  | loss  0.03 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 93 | valid err rate:  2.90% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  36400  | loss  0.04 | err rate  0.78%
# Minibatch  36500  | loss  0.04 | err rate  0.00%
# Minibatch  36600  | loss  0.03 | err rate  0.00%
# Minibatch  36700  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 94 | valid err rate:  2.89% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  36800  | loss  0.05 | err rate  1.56%
# Minibatch  36900  | loss  0.03 | err rate  0.78%
# Minibatch  37000  | loss  0.04 | err rate  0.78%
# Minibatch  37100  | loss  0.06 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 95 | valid err rate:  2.91% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  37200  | loss  0.04 | err rate  0.78%
# Minibatch  37300  | loss  0.03 | err rate  0.78%
# Minibatch  37400  | loss  0.03 | err rate  0.78%
# Minibatch  37500  | loss  0.03 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 96 | valid err rate:  2.89% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  37600  | loss  0.05 | err rate  0.78%
# Minibatch  37700  | loss  0.04 | err rate  0.00%
# Minibatch  37800  | loss  0.03 | err rate  0.00%
# Minibatch  37900  | loss  0.03 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 97 | valid err rate:  2.88% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  38000  | loss  0.05 | err rate  1.56%
# Minibatch  38100  | loss  0.03 | err rate  0.00%
# Minibatch  38200  | loss  0.02 | err rate  0.00%
# Minibatch  38300  | loss  0.02 | err rate  0.00%
# ----------------------------------------------------------
# After epoch 98 | valid err rate:  2.89% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  38400  | loss  0.07 | err rate  1.56%
# Minibatch  38500  | loss  0.10 | err rate  3.12%
# Minibatch  38600  | loss  0.03 | err rate  0.00%
# Minibatch  38700  | loss  0.05 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 99 | valid err rate:  2.91% | doing 136 epochs
# ----------------------------------------------------------
# Minibatch  38800  | loss  0.08 | err rate  2.34%
# Minibatch  38900  | loss  0.03 | err rate  0.00%
# Minibatch  39000  | loss  0.04 | err rate  0.78%
# Minibatch  39100  | loss  0.05 | err rate  1.25%
# -----------------------------------------------------------
# After epoch 100 | valid err rate:  2.88% | doing 136 epochs
# -----------------------------------------------------------
# Minibatch  39200  | loss  0.04 | err rate  0.00%
# Minibatch  39300  | loss  0.05 | err rate  2.34%
# Minibatch  39400  | loss  0.03 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 101 | valid err rate:  2.88% | doing 136 epochs
# -----------------------------------------------------------
# Minibatch  39500  | loss  0.03 | err rate  0.00%
# Minibatch  39600  | loss  0.06 | err rate  2.34%
# Minibatch  39700  | loss  0.04 | err rate  1.56%
# Minibatch  39800  | loss  0.05 | err rate  1.56%
# -----------------------------------------------------------
# After epoch 102 | valid err rate:  2.90% | doing 136 epochs
# -----------------------------------------------------------
# Minibatch  39900  | loss  0.02 | err rate  0.78%
# Minibatch  40000  | loss  0.03 | err rate  0.78%
# Minibatch  40100  | loss  0.03 | err rate  0.78%
# Minibatch  40200  | loss  0.04 | err rate  0.78%
# -----------------------------------------------------------
# After epoch 103 | valid err rate:  2.90% | doing 136 epochs
# -----------------------------------------------------------
# Minibatch  40300  | loss  0.03 | err rate  0.78%
# Minibatch  40400  | loss  0.03 | err rate  0.00%
# Minibatch  40500  | loss  0.04 | err rate  0.78%
# Minibatch  40600  | loss  0.02 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 104 | valid err rate:  2.90% | doing 136 epochs
# -----------------------------------------------------------
# Minibatch  40700  | loss  0.05 | err rate  1.56%
# Minibatch  40800  | loss  0.02 | err rate  0.00%
# Minibatch  40900  | loss  0.05 | err rate  0.78%
# Minibatch  41000  | loss  0.02 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 105 | valid err rate:  2.87% | doing 158 epochs
# -----------------------------------------------------------
# Minibatch  41100  | loss  0.05 | err rate  1.56%
# Minibatch  41200  | loss  0.03 | err rate  0.00%
# Minibatch  41300  | loss  0.04 | err rate  0.00%
# Minibatch  41400  | loss  0.05 | err rate  0.78%
# -----------------------------------------------------------
# After epoch 106 | valid err rate:  2.88% | doing 158 epochs
# -----------------------------------------------------------
# Minibatch  41500  | loss  0.03 | err rate  0.00%
# Minibatch  41600  | loss  0.07 | err rate  0.78%
# Minibatch  41700  | loss  0.06 | err rate  0.78%
# Minibatch  41800  | loss  0.04 | err rate  0.78%
# -----------------------------------------------------------
# After epoch 107 | valid err rate:  2.86% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  41900  | loss  0.03 | err rate  0.00%
# Minibatch  42000  | loss  0.03 | err rate  0.00%
# Minibatch  42100  | loss  0.01 | err rate  0.00%
# Minibatch  42200  | loss  0.04 | err rate  1.56%
# -----------------------------------------------------------
# After epoch 108 | valid err rate:  2.87% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  42300  | loss  0.04 | err rate  1.56%
# Minibatch  42400  | loss  0.03 | err rate  1.56%
# Minibatch  42500  | loss  0.06 | err rate  2.34%
# Minibatch  42600  | loss  0.05 | err rate  0.78%
# -----------------------------------------------------------
# After epoch 109 | valid err rate:  2.88% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  42700  | loss  0.02 | err rate  0.00%
# Minibatch  42800  | loss  0.05 | err rate  1.56%
# Minibatch  42900  | loss  0.04 | err rate  0.78%
# Minibatch  43000  | loss  0.03 | err rate  0.78%
# -----------------------------------------------------------
# After epoch 110 | valid err rate:  2.91% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  43100  | loss  0.05 | err rate  2.34%
# Minibatch  43200  | loss  0.05 | err rate  0.78%
# Minibatch  43300  | loss  0.04 | err rate  0.78%
# Minibatch  43400  | loss  0.02 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 111 | valid err rate:  2.88% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  43500  | loss  0.02 | err rate  0.00%
# Minibatch  43600  | loss  0.03 | err rate  0.00%
# Minibatch  43700  | loss  0.04 | err rate  0.78%
# -----------------------------------------------------------
# After epoch 112 | valid err rate:  2.87% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  43800  | loss  0.04 | err rate  0.78%
# Minibatch  43900  | loss  0.05 | err rate  0.78%
# Minibatch  44000  | loss  0.05 | err rate  0.78%
# Minibatch  44100  | loss  0.03 | err rate  1.56%
# -----------------------------------------------------------
# After epoch 113 | valid err rate:  2.87% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  44200  | loss  0.02 | err rate  0.00%
# Minibatch  44300  | loss  0.03 | err rate  0.00%
# Minibatch  44400  | loss  0.04 | err rate  0.00%
# Minibatch  44500  | loss  0.02 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 114 | valid err rate:  2.88% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  44600  | loss  0.03 | err rate  1.56%
# Minibatch  44700  | loss  0.03 | err rate  0.00%
# Minibatch  44800  | loss  0.04 | err rate  0.00%
# Minibatch  44900  | loss  0.03 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 115 | valid err rate:  2.86% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  45000  | loss  0.05 | err rate  1.56%
# Minibatch  45100  | loss  0.05 | err rate  1.56%
# Minibatch  45200  | loss  0.02 | err rate  0.00%
# Minibatch  45300  | loss  0.05 | err rate  1.56%
# -----------------------------------------------------------
# After epoch 116 | valid err rate:  2.88% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  45400  | loss  0.03 | err rate  0.00%
# Minibatch  45500  | loss  0.03 | err rate  0.00%
# Minibatch  45600  | loss  0.03 | err rate  0.78%
# Minibatch  45700  | loss  0.07 | err rate  1.56%
# -----------------------------------------------------------
# After epoch 117 | valid err rate:  2.86% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  45800  | loss  0.03 | err rate  0.00%
# Minibatch  45900  | loss  0.04 | err rate  0.00%
# Minibatch  46000  | loss  0.08 | err rate  1.56%
# Minibatch  46100  | loss  0.05 | err rate  1.56%
# -----------------------------------------------------------
# After epoch 118 | valid err rate:  2.88% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  46200  | loss  0.04 | err rate  0.78%
# Minibatch  46300  | loss  0.03 | err rate  0.00%
# Minibatch  46400  | loss  0.03 | err rate  0.00%
# Minibatch  46500  | loss  0.02 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 119 | valid err rate:  2.88% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  46600  | loss  0.03 | err rate  0.78%
# Minibatch  46700  | loss  0.04 | err rate  0.78%
# Minibatch  46800  | loss  0.05 | err rate  1.56%
# Minibatch  46900  | loss  0.02 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 120 | valid err rate:  2.86% | doing 161 epochs
# -----------------------------------------------------------
# Minibatch  47000  | loss  0.04 | err rate  0.78%
# Minibatch  47100  | loss  0.04 | err rate  0.78%
# Minibatch  47200  | loss  0.04 | err rate  0.78%
# Minibatch  47300  | loss  0.06 | err rate  1.56%
# -----------------------------------------------------------
# After epoch 121 | valid err rate:  2.85% | doing 182 epochs
# -----------------------------------------------------------
# Minibatch  47400  | loss  0.04 | err rate  0.78%
# Minibatch  47500  | loss  0.03 | err rate  0.78%
# Minibatch  47600  | loss  0.02 | err rate  0.00%
# Minibatch  47700  | loss  0.04 | err rate  0.78%
# -----------------------------------------------------------
# After epoch 122 | valid err rate:  2.83% | doing 184 epochs
# -----------------------------------------------------------
# Minibatch  47800  | loss  0.05 | err rate  0.78%
# Minibatch  47900  | loss  0.02 | err rate  0.00%
# Minibatch  48000  | loss  0.02 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 123 | valid err rate:  2.86% | doing 184 epochs
# -----------------------------------------------------------
# Minibatch  48100  | loss  0.04 | err rate  0.78%
# Minibatch  48200  | loss  0.06 | err rate  0.78%
# Minibatch  48300  | loss  0.03 | err rate  0.00%
# Minibatch  48400  | loss  0.05 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 124 | valid err rate:  2.86% | doing 184 epochs
# -----------------------------------------------------------
# Minibatch  48500  | loss  0.03 | err rate  0.78%
# Minibatch  48600  | loss  0.03 | err rate  0.78%
# Minibatch  48700  | loss  0.03 | err rate  0.78%
# Minibatch  48800  | loss  0.02 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 125 | valid err rate:  2.85% | doing 184 epochs
# -----------------------------------------------------------
# Minibatch  48900  | loss  0.02 | err rate  0.00%
# Minibatch  49000  | loss  0.03 | err rate  0.00%
# Minibatch  49100  | loss  0.04 | err rate  0.00%
# Minibatch  49200  | loss  0.06 | err rate  1.56%
# -----------------------------------------------------------
# After epoch 126 | valid err rate:  2.85% | doing 184 epochs
# -----------------------------------------------------------
# Minibatch  49300  | loss  0.04 | err rate  1.56%
# Minibatch  49400  | loss  0.04 | err rate  0.78%
# Minibatch  49500  | loss  0.04 | err rate  0.00%
# Minibatch  49600  | loss  0.05 | err rate  0.78%
# -----------------------------------------------------------
# After epoch 127 | valid err rate:  2.85% | doing 184 epochs
# -----------------------------------------------------------
# Minibatch  49700  | loss  0.03 | err rate  0.00%
# Minibatch  49800  | loss  0.03 | err rate  0.78%
# Minibatch  49900  | loss  0.03 | err rate  0.78%
# Minibatch  50000  | loss  0.02 | err rate  0.00%
# -----------------------------------------------------------
# After epoch 128 | valid err rate:  2.84% | doing 184 epochs
# -----------------------------------------------------------
# Minibatch  50100  | loss  0.02 | err rate  0.00%
# Minibatch  50200  | loss  0.03 | err rate  0.00%
# Minibatch  50300  | loss  0.02 | err rate  0.00%
# Minibatch  50400  | loss  0.03 | err rate  1.56%
# -----------------------------------------------------------
# After epoch 129 | valid err rate:  2.86% | doing 184 epochs
# -----------------------------------------------------------
# Minibatch  50500  | loss  0.06 | err rate  0.78%
# Minibatch  50600  | loss  0.03 | err rate  1.56%
# Minibatch  50700  | loss  0.04 | err rate  0.78%
# Minibatch  50800  | loss  0.03 | err rate  0.00%
# -----------------------------------------------------------
# ...
# Minibatch 748000  | loss  0.01 | err rate  0.00%
# Minibatch 748100  | loss  0.01 | err rate  0.00%
# Minibatch 748200  | loss  0.01 | err rate  0.00%
# Minibatch 748300  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1914 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 748400  | loss  0.01 | err rate  0.00%
# Minibatch 748500  | loss  0.01 | err rate  0.00%
# Minibatch 748600  | loss  0.02 | err rate  0.00%
# Minibatch 748700  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1915 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 748800  | loss  0.01 | err rate  0.00%
# Minibatch 748900  | loss  0.01 | err rate  0.00%
# Minibatch 749000  | loss  0.01 | err rate  0.00%
# Minibatch 749100  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1916 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 749200  | loss  0.01 | err rate  0.00%
# Minibatch 749300  | loss  0.01 | err rate  0.00%
# Minibatch 749400  | loss  0.01 | err rate  0.00%
# Minibatch 749500  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1917 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 749600  | loss  0.01 | err rate  0.00%
# Minibatch 749700  | loss  0.02 | err rate  0.00%
# Minibatch 749800  | loss  0.02 | err rate  0.00%
# Minibatch 749900  | loss  0.02 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1918 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 750000  | loss  0.02 | err rate  0.00%
# Minibatch 750100  | loss  0.01 | err rate  0.00%
# Minibatch 750200  | loss  0.02 | err rate  0.78%
# Minibatch 750300  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1919 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 750400  | loss  0.01 | err rate  0.00%
# Minibatch 750500  | loss  0.02 | err rate  0.00%
# Minibatch 750600  | loss  0.01 | err rate  0.00%
# Minibatch 750700  | loss  0.02 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1920 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 750800  | loss  0.01 | err rate  0.00%
# Minibatch 750900  | loss  0.01 | err rate  0.00%
# Minibatch 751000  | loss  0.01 | err rate  0.00%
# Minibatch 751100  | loss  0.02 | err rate  0.78%
# -------------------------------------------------------------
# After epoch 1921 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 751200  | loss  0.01 | err rate  0.00%
# Minibatch 751300  | loss  0.01 | err rate  0.00%
# Minibatch 751400  | loss  0.01 | err rate  0.00%
# Minibatch 751500  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1922 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 751600  | loss  0.01 | err rate  0.00%
# Minibatch 751700  | loss  0.01 | err rate  0.00%
# Minibatch 751800  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1923 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 751900  | loss  0.02 | err rate  0.00%
# Minibatch 752000  | loss  0.02 | err rate  0.00%
# Minibatch 752100  | loss  0.01 | err rate  0.00%
# Minibatch 752200  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1924 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 752300  | loss  0.01 | err rate  0.00%
# Minibatch 752400  | loss  0.01 | err rate  0.00%
# Minibatch 752500  | loss  0.01 | err rate  0.00%
# Minibatch 752600  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1925 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 752700  | loss  0.01 | err rate  0.00%
# Minibatch 752800  | loss  0.01 | err rate  0.00%
# Minibatch 752900  | loss  0.01 | err rate  0.00%
# Minibatch 753000  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1926 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 753100  | loss  0.01 | err rate  0.00%
# Minibatch 753200  | loss  0.02 | err rate  0.00%
# Minibatch 753300  | loss  0.01 | err rate  0.00%
# Minibatch 753400  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1927 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 753500  | loss  0.01 | err rate  0.00%
# Minibatch 753600  | loss  0.02 | err rate  0.00%
# Minibatch 753700  | loss  0.04 | err rate  0.78%
# Minibatch 753800  | loss  0.02 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1928 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 753900  | loss  0.02 | err rate  0.00%
# Minibatch 754000  | loss  0.01 | err rate  0.00%
# Minibatch 754100  | loss  0.01 | err rate  0.00%
# Minibatch 754200  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1929 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 754300  | loss  0.02 | err rate  0.00%
# Minibatch 754400  | loss  0.01 | err rate  0.00%
# Minibatch 754500  | loss  0.02 | err rate  0.00%
# Minibatch 754600  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1930 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 754700  | loss  0.02 | err rate  0.00%
# Minibatch 754800  | loss  0.00 | err rate  0.00%
# Minibatch 754900  | loss  0.02 | err rate  0.78%
# Minibatch 755000  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1931 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 755100  | loss  0.01 | err rate  0.00%
# Minibatch 755200  | loss  0.02 | err rate  0.00%
# Minibatch 755300  | loss  0.02 | err rate  0.00%
# Minibatch 755400  | loss  0.02 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1932 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 755500  | loss  0.01 | err rate  0.00%
# Minibatch 755600  | loss  0.01 | err rate  0.00%
# Minibatch 755700  | loss  0.02 | err rate  0.00%
# Minibatch 755800  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1933 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 755900  | loss  0.01 | err rate  0.00%
# Minibatch 756000  | loss  0.01 | err rate  0.00%
# Minibatch 756100  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1934 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 756200  | loss  0.01 | err rate  0.00%
# Minibatch 756300  | loss  0.01 | err rate  0.00%
# Minibatch 756400  | loss  0.01 | err rate  0.00%
# Minibatch 756500  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1935 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 756600  | loss  0.02 | err rate  0.00%
# Minibatch 756700  | loss  0.02 | err rate  0.78%
# Minibatch 756800  | loss  0.01 | err rate  0.00%
# Minibatch 756900  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1936 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 757000  | loss  0.01 | err rate  0.00%
# Minibatch 757100  | loss  0.01 | err rate  0.00%
# Minibatch 757200  | loss  0.01 | err rate  0.00%
# Minibatch 757300  | loss  0.02 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1937 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 757400  | loss  0.02 | err rate  0.78%
# Minibatch 757500  | loss  0.02 | err rate  0.00%
# Minibatch 757600  | loss  0.02 | err rate  0.00%
# Minibatch 757700  | loss  0.02 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1938 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 757800  | loss  0.01 | err rate  0.00%
# Minibatch 757900  | loss  0.01 | err rate  0.00%
# Minibatch 758000  | loss  0.01 | err rate  0.00%
# Minibatch 758100  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1939 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 758200  | loss  0.01 | err rate  0.00%
# Minibatch 758300  | loss  0.02 | err rate  0.00%
# Minibatch 758400  | loss  0.01 | err rate  0.00%
# Minibatch 758500  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1940 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 758600  | loss  0.01 | err rate  0.78%
# Minibatch 758700  | loss  0.02 | err rate  0.00%
# Minibatch 758800  | loss  0.01 | err rate  0.00%
# Minibatch 758900  | loss  0.03 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1941 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 759000  | loss  0.01 | err rate  0.00%
# Minibatch 759100  | loss  0.02 | err rate  0.00%
# Minibatch 759200  | loss  0.02 | err rate  0.00%
# Minibatch 759300  | loss  0.02 | err rate  0.78%
# -------------------------------------------------------------
# After epoch 1942 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 759400  | loss  0.02 | err rate  0.00%
# Minibatch 759500  | loss  0.01 | err rate  0.00%
# Minibatch 759600  | loss  0.02 | err rate  0.78%
# Minibatch 759700  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1943 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 759800  | loss  0.01 | err rate  0.00%
# Minibatch 759900  | loss  0.02 | err rate  0.78%
# Minibatch 760000  | loss  0.03 | err rate  0.78%
# Minibatch 760100  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1944 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 760200  | loss  0.01 | err rate  0.00%
# Minibatch 760300  | loss  0.02 | err rate  0.00%
# Minibatch 760400  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1945 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 760500  | loss  0.02 | err rate  0.00%
# Minibatch 760600  | loss  0.01 | err rate  0.00%
# Minibatch 760700  | loss  0.01 | err rate  0.00%
# Minibatch 760800  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1946 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 760900  | loss  0.01 | err rate  0.00%
# Minibatch 761000  | loss  0.01 | err rate  0.00%
# Minibatch 761100  | loss  0.02 | err rate  0.00%
# Minibatch 761200  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1947 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 761300  | loss  0.01 | err rate  0.00%
# Minibatch 761400  | loss  0.02 | err rate  0.00%
# Minibatch 761500  | loss  0.02 | err rate  0.00%
# Minibatch 761600  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1948 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 761700  | loss  0.01 | err rate  0.00%
# Minibatch 761800  | loss  0.01 | err rate  0.00%
# Minibatch 761900  | loss  0.01 | err rate  0.00%
# Minibatch 762000  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1949 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 762100  | loss  0.01 | err rate  0.00%
# Minibatch 762200  | loss  0.01 | err rate  0.00%
# Minibatch 762300  | loss  0.01 | err rate  0.00%
# Minibatch 762400  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1950 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 762500  | loss  0.01 | err rate  0.00%
# Minibatch 762600  | loss  0.02 | err rate  0.00%
# Minibatch 762700  | loss  0.01 | err rate  0.00%
# Minibatch 762800  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1951 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 762900  | loss  0.01 | err rate  0.00%
# Minibatch 763000  | loss  0.01 | err rate  0.00%
# Minibatch 763100  | loss  0.01 | err rate  0.00%
# Minibatch 763200  | loss  0.03 | err rate  0.78%
# -------------------------------------------------------------
# After epoch 1952 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 763300  | loss  0.01 | err rate  0.00%
# Minibatch 763400  | loss  0.02 | err rate  0.00%
# Minibatch 763500  | loss  0.01 | err rate  0.00%
# Minibatch 763600  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1953 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 763700  | loss  0.01 | err rate  0.00%
# Minibatch 763800  | loss  0.01 | err rate  0.00%
# Minibatch 763900  | loss  0.01 | err rate  0.00%
# Minibatch 764000  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1954 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 764100  | loss  0.01 | err rate  0.00%
# Minibatch 764200  | loss  0.01 | err rate  0.00%
# Minibatch 764300  | loss  0.01 | err rate  0.00%
# Minibatch 764400  | loss  0.01 | err rate  0.00%
# -------------------------------------------------------------
# After epoch 1955 | valid err rate:  2.48% | doing 2578 epochs
# -------------------------------------------------------------
# Minibatch 764500  | loss  0.01 | err rate  0.00%

# %% [markdown]
# # Problem 3: Dropout [2p]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout. The best
# results with dropout are below 1%!
#
# Remember to turn off dropout during testing, using `model.train_mode()` and `model.eval_mode()`!
#
# Hint: Use [torch.nn.functional.dropout](http://pytorch.org/docs/master/nn.html#torch.nn.functional.dropout).
#
# Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 4: Data Augmentation [1p]
#
# Apply data augmentation methods (e.g. rotations, noise, crops) when training networks on MNIST, to significantly reduce test error rate for your network. You can use functions from the [torchvision.transforms](http://pytorch.org/docs/master/torchvision/transforms.html) module.

# %% [markdown]
# # Problem 5: Batch Normalization [1p]
#
# *Covariate shift* is a phenomenon associated with training deep models. Simply put, weight changes in early layers cause major changes in distribution of inputs to later layers, making it difficult to train later layers.
#
# [Batch Normalization](https://arxiv.org/abs/1502.03167) addresses this problem by normalizing distributions of inputs to layers within mini-batches. It typically allows to train networks faster and/or with higher learning rates, lessens the importance
# of initialization and might eliminate the need for Dropout.
#
# Implement Batch Normalization and compare with regular training of MNIST models.
#
# Remember to use the batch statistics during model training and to use an average of training batch statistics during model evaluation. For details please consult the paper.

# %% [markdown]
# # Problem 6: Norm Constraints [1p bonus]
#
# Implement norm constraints, i.e. instead of weight decay, that tries to set
# all weights to small values, apply a limit on the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").
#
# Please consult the Dropout paper (http://arxiv.org/pdf/1207.0580.pdf) for details.

# %% [markdown]
# # Problem 6: Polyak Averaging [1p bonus]
#
# Implement Polyak averaging. For each parameter $\theta$
# keep a separate, exponentially decayed average of the past values
# $$
# \bar{\theta}_n = \alpha_p\bar{\theta}_{n-1} + (1-\alpha_p)\theta_n.
# $$
# Use that average when evaluating the model on the test set.
# Validate the approach by training a model on the MNIST dataset.

# %% [markdown]
# # Problem 7: Convolutional Network [2p bonus]
#
# Use convolutional and max-pooling layers (`torch.nn.functional.conv2d`, `torch.nn.functional.max_pool2d`) and (without dropout) get a test error rate below 1.5%.
